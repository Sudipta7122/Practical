# %% [markdown]
# # Name: Mondal Sudipta Jayanta
# # Class: BE-B
# # Roll No: B212012

# %% [markdown]
# ## Practical 4 : Implement Gradient Descent Algorithm to find the local minima of a function.For example, find the local minima of the function y=(x+3)² starting from the point x=2.

# %%
x=2
lr=0.012
precision = 0.000001

previous_step_size= 1
max_iter=10000
iter=0

gf = lambda x:(x+3)**2

# %%
gd = []

# %%
while (precision < previous_step_size and iter < max_iter):
    prv = x 
    x = x-lr*gf(prv)
    previous_step_size= abs(x - prv)
    iter+=1
    print("Iteration Value : ", iter, "value :", x)
    gd.append(x)
# Out:
# Iteration Value :  1 value : 1.7
# Iteration Value :  2 value : 1.43492
# Iteration Value :  3 value : 1.1988978151232
# Iteration Value :  4 value : 0.9873289007810434
# Iteration Value :  5 value : 0.7965433996249982
# Iteration Value :  6 value : 0.6235784982021646
# Iteration Value :  7 value : 0.46601464461056796
# Iteration Value :  8 value : 0.3218555544107089
# Iteration Value :  9 value : 0.18943886251827757
# Iteration Value :  10 value : 0.06736861942537495
# Iteration Value :  11 value : -0.04553638354385142
# Iteration Value :  12 value : -0.15028264667540914
# Iteration Value :  13 value : -0.2477333146014809
# Iteration Value :  14 value : -0.3386329774921355
# Iteration Value :  15 value : -0.423627470634044
# Iteration Value :  16 value : -0.5032798155549024
# Iteration Value :  17 value : -0.5780831557078892
# Iteration Value :  18 value : -0.6484713301158794
# Iteration Value :  19 value : -0.7148275751393232
# Iteration Value :  20 value : -0.7774917312754467
# ...

# %%
import matplotlib.pyplot as plt
plt.plot(gd)
